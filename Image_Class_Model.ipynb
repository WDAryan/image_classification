# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers

# %%
data_train_path = 'Fruits_Vegetables/train'
data_test_path = 'Fruits_Vegetables/test'
data_val_path = 'Fruits_Vegetables/validation'

# %%
img_width = 180
img_height =180

# %%
data_train = tf.keras.utils.image_dataset_from_directory(
    data_train_path,
    shuffle=True,
    image_size=(img_width, img_height),
    batch_size=32,
    validation_split=False)
# Out:
# Found 3115 files belonging to 36 classes.

# %%
data_cat = data_train.class_names

# %%
data_cat
# Out:
# ['apple',
#  'banana',
#  'beetroot',
#  'bell pepper',
#  'cabbage',
#  'capsicum',
#  'carrot',
#  'cauliflower',
#  'chilli pepper',
#  'corn',
#  'cucumber',
#  'eggplant',
#  'garlic',
#  'ginger',
#  'grapes',
#  'jalepeno',
#  'kiwi',
#  'lemon',
#  'lettuce',
#  'mango',
#  'onion',
#  'orange',
#  'paprika',
#  'pear',
#  'peas',
#  'pineapple',
#  'pomegranate',
#  'potato',
#  'raddish',
#  'soy beans',
#  'spinach',
#  'sweetcorn',
#  'sweetpotato',
#  'tomato',
#  'turnip',
#  'watermelon']

# %%
data_val = tf.keras.utils.image_dataset_from_directory(data_val_path,
                                                       image_size=(img_height,img_width),
                                                       batch_size=32,
                                                        shuffle=False,
                                                       validation_split=False)
# Out:
# Found 351 files belonging to 36 classes.

# %%
data_test = tf.keras.utils.image_dataset_from_directory(
data_test_path,
    image_size=(img_height,img_width),
    shuffle=False,
    batch_size=32,
    validation_split=False
)
# Out:
# Found 359 files belonging to 36 classes.

# %%
plt.figure(figsize=(10,10))
for image, labels in data_train.take(1):
    for i in range(9):
        plt.subplot(3,3,i+1)
        plt.imshow(image[i].numpy().astype('uint8'))
        plt.title(data_cat[labels[i]])
        plt.axis('off')

# %%
from tensorflow.keras.models import Sequential

# %%
data_train
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
model = Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(16, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32,3, padding='same',activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dropout(0.2),
    layers.Dense(128),
    layers.Dense(len(data_cat))
                  
])

# %%
model.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

# %%
epochs_size = 30
history = model.fit(data_train, validation_data=data_val, epochs=epochs_size)
# Out:
# Epoch 1/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 29s 259ms/step - accuracy: 0.0713 - loss: 3.9830 - val_accuracy: 0.3932 - val_loss: 2.3060
# Epoch 2/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 25s 247ms/step - accuracy: 0.2942 - loss: 2.4830 - val_accuracy: 0.6154 - val_loss: 1.5087
# Epoch 3/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 24s 235ms/step - accuracy: 0.4565 - loss: 1.8909 - val_accuracy: 0.8006 - val_loss: 0.8926
# Epoch 4/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 24s 234ms/step - accuracy: 0.6341 - loss: 1.2499 - val_accuracy: 0.9003 - val_loss: 0.4919
# Epoch 5/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 24s 243ms/step - accuracy: 0.7946 - loss: 0.7172 - val_accuracy: 0.9060 - val_loss: 0.4041
# Epoch 6/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 24s 239ms/step - accuracy: 0.8642 - loss: 0.4736 - val_accuracy: 0.9345 - val_loss: 0.4524
# Epoch 7/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 24s 241ms/step - accuracy: 0.9203 - loss: 0.3222 - val_accuracy: 0.9516 - val_loss: 0.2687
# Epoch 8/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 24s 238ms/step - accuracy: 0.9423 - loss: 0.2178 - val_accuracy: 0.9430 - val_loss: 0.3729
# Epoch 9/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 24s 239ms/step - accuracy: 0.9614 - loss: 0.1726 - val_accuracy: 0.9573 - val_loss: 0.3102
# Epoch 10/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 24s 239ms/step - accuracy: 0.9657 - loss: 0.1362 - val_accuracy: 0.9573 - val_loss: 0.3303
# Epoch 11/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 24s 233ms/step - accuracy: 0.9737 - loss: 0.1358 - val_accuracy: 0.9573 - val_loss: 0.3812
# Epoch 12/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 24s 236ms/step - accuracy: 0.9734 - loss: 0.1318 - val_accuracy: 0.9544 - val_loss: 0.3249
# Epoch 13/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 24s 243ms/step - accuracy: 0.9719 - loss: 0.1221 - val_accuracy: 0.9573 - val_loss: 0.3299
# Epoch 14/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 23s 231ms/step - accuracy: 0.9698 - loss: 0.1084 - val_accuracy: 0.9516 - val_loss: 0.3804
# Epoch 15/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 24s 247ms/step - accuracy: 0.9654 - loss: 0.1265 - val_accuracy: 0.9430 - val_loss: 0.4864
# Epoch 16/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 24s 236ms/step - accuracy: 0.9780 - loss: 0.0923 - val_accuracy: 0.9573 - val_loss: 0.3810
# Epoch 17/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 23s 234ms/step - accuracy: 0.9833 - loss: 0.1040 - val_accuracy: 0.9516 - val_loss: 0.3358
# Epoch 18/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 23s 236ms/step - accuracy: 0.9858 - loss: 0.0670 - val_accuracy: 0.9573 - val_loss: 0.3242
# Epoch 19/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 24s 245ms/step - accuracy: 0.9778 - loss: 0.1104 - val_accuracy: 0.9601 - val_loss: 0.2729
# Epoch 20/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 25s 247ms/step - accuracy: 0.9808 - loss: 0.0819 - val_accuracy: 0.9573 - val_loss: 0.3350
# Epoch 21/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 25s 247ms/step - accuracy: 0.9828 - loss: 0.0757 - val_accuracy: 0.9573 - val_loss: 0.3564
# Epoch 22/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 25s 251ms/step - accuracy: 0.9826 - loss: 0.0707 - val_accuracy: 0.9573 - val_loss: 0.2742
# Epoch 23/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 24s 235ms/step - accuracy: 0.9865 - loss: 0.0580 - val_accuracy: 0.9630 - val_loss: 0.2860
# Epoch 24/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 24s 240ms/step - accuracy: 0.9841 - loss: 0.0595 - val_accuracy: 0.9630 - val_loss: 0.3082
# Epoch 25/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 24s 235ms/step - accuracy: 0.9797 - loss: 0.0830 - val_accuracy: 0.9573 - val_loss: 0.3110
# Epoch 26/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 28s 274ms/step - accuracy: 0.9844 - loss: 0.0700 - val_accuracy: 0.9573 - val_loss: 0.3877
# Epoch 27/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 24s 237ms/step - accuracy: 0.9855 - loss: 0.0538 - val_accuracy: 0.9601 - val_loss: 0.3321
# Epoch 28/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 23s 226ms/step - accuracy: 0.9852 - loss: 0.0638 - val_accuracy: 0.9601 - val_loss: 0.3296
# Epoch 29/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 23s 226ms/step - accuracy: 0.9847 - loss: 0.0439 - val_accuracy: 0.9601 - val_loss: 0.3633
# Epoch 30/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 22s 225ms/step - accuracy: 0.9813 - loss: 0.0586 - val_accuracy: 0.9573 - val_loss: 0.3356

# %%
epochs_range = range(epochs_size)
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(epochs_range,history.history['accuracy'],label = 'Training Accuracy')
plt.plot(epochs_range, history.history['val_accuracy'],label = 'Validation Accuracy')
plt.title('Accuracy')

plt.subplot(1,2,2)
plt.plot(epochs_range,history.history['loss'],label = 'Training Loss')
plt.plot(epochs_range, history.history['val_loss'],label = 'Validation Loss')
plt.title('Loss')
# Out:
# Text(0.5, 1.0, 'Loss')

# %%
image = 'Image_2.jpg'
image = tf.keras.utils.load_img(image, target_size=(img_height,img_width))
img_arr = tf.keras.utils.array_to_img(image)
img_bat=tf.expand_dims(img_arr,0)

# %%
predict = model.predict(img_bat)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step

# %%
score = tf.nn.softmax(predict)

# %%
print('Veg/Fruit in image is {} with accuracy of {:0.2f}'.format(data_cat[np.argmax(score)],np.max(score)*100))
# Out:
# Veg/Fruit in image is grapes with accuracy of 100.00

# %%
model.save('Image_classify.keras')
